# %% [markdown]
# # Parser FF

# %%
import csv
import pandas as pd
import numpy as np

with open('z_atomlist.tmp','r') as atom_list:
    df1=pd.read_csv(atom_list, header=None,index_col=None,sep='\t',names=[';Residue','AtName','AtType','Charge'])
    
with open('z_atoms.tmp','r') as atoms:
    df2=pd.read_csv(atoms, header=None,index_col=None,sep='\t',names=[';AtType','Mass','Sigma','Epsilon'])

# %%
df1
# Out:
#      ;Residue AtName    AtType     Charge
# 0         HOH     OW        OW     -0.834
# 1         HOH    HW1        HW      0.417
# 2         HOH    HW2        HW      0.417
# 3         HO4     OW  OW_tip4p       0.00
# 4         HO4    HW1        HW       0.52
# 5         HO4    HW2        HW       0.52
# 6         HO4     MW        MW      -1.04
# 7         IB+     IB        IB    1.00000
# 8          CA     CA        C0    2.00000
# 9          CL     CL        Cl   -1.00000
# 10        NaN    NaN        Na    1.00000
# 11         MG     MG        MG    2.00000
# 12          K      K         K    1.00000
# 13         RB     RB        Rb    1.00000
# 14         CS     CS        Cs    1.00000
# 15         LI     LI        Li    1.00000
# 16         ZN     ZN        Zn    2.00000
# 17        URE      C         C   0.880229
# 18        URE      O         O  -0.613359
# 19        URE     N1         N  -0.923545
# 20        URE    H11         H   0.395055
# 21        URE    H12         H   0.395055
# 22        URE     N2         N  -0.923545
# 23        URE    H21         H   0.395055
# 24        URE    H22         H   0.395055
# 25        ACE   HH31        HC    0.11230
# 26        ACE    CH3        CT   -0.36620
# 27        ACE   HH32        HC    0.11230
# 28        ACE   HH33        HC    0.11230
# 29        ACE      C         C    0.59720
# ...       ...    ...       ...        ...
# 1301     NCYX     H1         H    0.18150
# 1302     NCYX     H2         H    0.18150
# 1303     NCYX     H3         H    0.18150
# 1304     NCYX     CA        CT    0.10550
# 1305     NCYX     HA        HP    0.09220
# 1306     NCYX     CB        CT   -0.02770
# 1307     NCYX    HB1        H1    0.06800
# 1308     NCYX    HB2        H1    0.06800
# 1309     NCYX     SG         S   -0.09840
# 1310     NCYX      C         C    0.61230
# 1311     NCYX      O         O   -0.57130
# 1312     NMET      N        N3    0.15920
# 1313     NMET     H1         H    0.19840
# 1314     NMET     H2         H    0.19840
# 1315     NMET     H3         H    0.19840
# 1316     NMET     CA        CT    0.02210
# 1317     NMET     HA        HP    0.11160
# 1318     NMET     CB        CT    0.08650
# 1319     NMET    HB1        HC    0.01250
# 1320     NMET    HB2        HC    0.01250
# 1321     NMET     CG        CT    0.03340
# 1322     NMET    HG1        H1    0.02920
# 1323     NMET    HG2        H1    0.02920
# 1324     NMET     SD         S   -0.27740
# 1325     NMET     CE        CT   -0.03410
# 1326     NMET    HE1        H1    0.05970
# 1327     NMET    HE2        H1    0.05970
# 1328     NMET    HE3        H1    0.05970
# 1329     NMET      C         C    0.61230
# 1330     NMET      O         O   -0.57130
#
# [1331 rows x 4 columns]

# %%
df2,df1
# Out:
#        ;AtType      Mass     Sigma   Epsilon
# 0           Br   79.9000  0.000000  0.000000
# 1            C   12.0100  0.339967  0.359824
# 2           CA   12.0100  0.339967  0.359824
# 3           CB   12.0100  0.339967  0.359824
# 4           CC   12.0100  0.339967  0.359824
# 5           CK   12.0100  0.339967  0.359824
# 6           CM   12.0100  0.339967  0.359824
# 7           CN   12.0100  0.339967  0.359824
# 8           CQ   12.0100  0.339967  0.359824
# 9           CR   12.0100  0.339967  0.359824
# 10          CT   12.0100  0.339967  0.457730
# 11          CV   12.0100  0.339967  0.359824
# 12          CW   12.0100  0.339967  0.359824
# 13          C*   12.0100  0.339967  0.359824
# 14          C0   40.0800  0.305240  1.923760
# 15           F   19.0000  0.311815  0.255224
# 16           H    1.0080  0.106908  0.065689
# 17          HC    1.0080  0.264953  0.065689
# 18          H1    1.0080  0.247135  0.065689
# 19          H2    1.0080  0.229317  0.065689
# 20          H3    1.0080  0.211499  0.065689
# 21          HA    1.0080  0.259964  0.062760
# 22          H4    1.0080  0.251055  0.062760
# 23          H5    1.0080  0.242146  0.062760
# 24          HO    1.0080  0.000000  0.000000
# 25          HS    1.0080  0.106908  0.065689
# 26          HW    1.0080  0.000000  0.000000
# 27          HP    1.0080  0.195998  0.065689
# 28           I  126.9000  0.418722  1.673600
# 29          Cl   35.4500  0.440104  0.418400
# ..         ...       ...       ...       ...
# 36          NC   14.0100  0.325000  0.711280
# 37          N2   14.0100  0.325000  0.711280
# 38          N3   14.0100  0.325000  0.711280
# 39          N*   14.0100  0.325000  0.711280
# 40           O   16.0000  0.295992  0.878640
# 41          OW   16.0000  0.315061  0.636386
# 42          OH   16.0000  0.306647  0.880314
# 43          OS   16.0000  0.300001  0.711280
# 44          O2   16.0000  0.295992  0.878640
# 45           P   30.9700  0.374177  0.836800
# 46           S   32.0600  0.356359  1.046000
# 47          SH   32.0600  0.356359  1.046000
# 48          CU   63.5500  0.339967  0.359824
# 49          FE   55.0000  0.000000  0.000000
# 50           K   39.1000  0.473602  0.001372
# 51          Rb   85.4700  0.526699  0.000711
# 52          Cs  132.9000  0.604920  0.000337
# 53      OW_spc   15.9994  0.316557  0.650629
# 54      HW_spc    1.0080  0.000000  0.000000
# 55          Li    6.9400  0.202590  0.076567
# 56          Zn   65.4000  0.195998  0.052300
# 57  HW_tip4pew    1.0080  0.000000  0.000000
# 58  OW_tip4pew   16.0000  0.316435  0.680946
# 59    HW_tip4p    1.0080  0.000000  0.000000
# 60    OW_tip4p   16.0000  0.315365  0.648520
# 61    HW_tip5p    1.0080  0.000000  0.000000
# 62    OW_tip5p   16.0000  0.312000  0.669440
# 63          MW    0.0000  0.000000  0.000000
# 64        MCH3    0.0000  0.000000  0.000000
# 65        MNH3    0.0000  0.000000  0.000000
#
# [66 rows x 4 columns]
